# %% [markdown]
# Rough notebook for testing out functionality

# %%
import os
import sys
import numpy as np
import pandas as pd

# %%
from importlib import reload

# %%
pd.options.display.max_columns=500
pd.options.display.max_colwidth=500
pd.options.display.max_rows=500

# %%
sys.path.append('../../ab_testing_utils/')

# %%
import conversion_rate_utils

# %%
reload(conversion_rate_utils)
# Out:
# <module 'conversion_rate_utils' from '/Users/danielokeeffe/Documents/src/stats_utils/stats_utils/notebooks/scratch_work/../../ab_testing_utils/conversion_rate_utils.py'>

# %%
test_experiment = conversion_rate_utils.ConversionExperiment()

# %%
monthly_num_observations = 30000
baseline_conversion_rate = 0.1
n_variants = 2
alpha = 0.05
power = 0.8

# %%
df_mde = test_experiment.create_mde_table(monthly_num_obs=monthly_num_observations, baseline_conversion_rate=baseline_conversion_rate, alpha=alpha, power=power)

# %%
df_mde.head()
# Out:
#      mde  new_conversion_rate_upper_bound  new_conversion_rate_lower_bound  \
# 0  0.001                           0.1001                           0.0999
# 1  0.002                           0.1002                           0.0998
# 2  0.003                           0.1003                           0.0997
# 3  0.004                           0.1004                           0.0996
# 4  0.005                           0.1005                           0.0995
#
#    total_sample_size  sample_size_per_variant    days  weeks  \
# 0          282559670                141279835  282560  40366
# 1           70639918                 35319959   70640  10092
# 2           31395518                 15697759   31396   4486
# 3           17659980                  8829990   17660   2523
# 4           11302386                  5651193   11303   1615
#
#    monthly_additional_conversions_upper  monthly_additional_conversions_lower
# 0                                     3                                    -3
# 1                                     6                                    -6
# 2                                     9                                    -9
# 3                                    12                                   -12
# 4                                    15                                   -15

# %%
df_mde.query('mde == 0.05')
# Out:
#      mde  new_conversion_rate_upper_bound  new_conversion_rate_lower_bound  \
# 49  0.05                            0.105                            0.095
#
#     total_sample_size  sample_size_per_variant  days  weeks  \
# 49             113024                    56512   114     17
#
#     monthly_additional_conversions_upper  monthly_additional_conversions_lower
# 49                                   150                                  -150

# %%
test_experiment.make_mde_plot(df_=df_mde, min_weeks=2, max_weeks=8)
